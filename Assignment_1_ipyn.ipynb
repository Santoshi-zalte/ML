# %% [markdown]
# <a href="https://colab.research.google.com/github/Santoshi-zalte/LP2_-program/blob/main/Assignment_1_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(csv_url, header = None)

# %%
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']
iris = pd.read_csv(csv_url, names = col_names)
iris
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head(n=5)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail(n=5)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width',
#        'Species'],
#       dtype='object')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Species          object
# dtype: object

# %%
iris.columns.values
# Out:
# array(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width',
#        'Species'], dtype=object)

# %%
iris.describe(include='all')
# Out:
#         Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN

# %%
iris['Sepal_Width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: Sepal_Width, Length: 150, dtype: float64

# %%
iris.sort_index(axis=1,
ascending=False)
# Out:
#             Species  Sepal_Width  Sepal_Length  Petal_Width  Petal_Length
# 0       Iris-setosa          3.5           5.1          0.2           1.4
# 1       Iris-setosa          3.0           4.9          0.2           1.4
# 2       Iris-setosa          3.2           4.7          0.2           1.3
# 3       Iris-setosa          3.1           4.6          0.2           1.5
# 4       Iris-setosa          3.6           5.0          0.2           1.4
# ..              ...          ...           ...          ...           ...
# 145  Iris-virginica          3.0           6.7          2.3           5.2
# 146  Iris-virginica          2.5           6.3          1.9           5.0
# 147  Iris-virginica          3.0           6.5          2.0           5.2
# 148  Iris-virginica          3.4           6.2          2.3           5.4
# 149  Iris-virginica          3.0           5.9          1.8           5.1
#
# [150 rows x 5 columns]

# %%
iris.sort_values(by="Sepal_Length")
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.iloc[5]
# Out:
# Sepal_Length            5.4
# Sepal_Width             3.9
# Petal_Length            1.7
# Petal_Width             0.4
# Species         Iris-setosa
# Name: 5, dtype: object

# %%
iris[0:3]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
iris.loc[:, ["Sepal_Length","Petal_Length"]]
# Out:
#      Sepal_Length  Petal_Length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
iris.iloc[:3, :5]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
iris.iloc[:5, :3]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4

# %%
iris.iloc[:7, :6]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa

# %%
iris.iloc[3:5, 0:2]
# Out:
#    Sepal_Length  Sepal_Width
# 3           4.6          3.1
# 4           5.0          3.6

# %%
iris.iloc[[1, 2,4], [0, 2]]
# Out:
#    Sepal_Length  Petal_Length
# 1           4.9           1.4
# 2           4.7           1.3
# 4           5.0           1.4

# %%
iris.iloc[1:3, :]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
iris.iloc[:, 1:3]
# Out:
#      Sepal_Width  Petal_Length
# 0            3.5           1.4
# 1            3.0           1.4
# 2            3.2           1.3
# 3            3.1           1.5
# 4            3.6           1.4
# ..           ...           ...
# 145          3.0           5.2
# 146          2.5           5.0
# 147          3.0           5.2
# 148          3.4           5.4
# 149          3.0           5.1
#
# [150 rows x 2 columns]

# %%
iris.iloc[1, 1]
# Out:
# 3.0

# %%
iris[5:].iloc[5]
# Out:
# Sepal_Length            5.4
# Sepal_Width             3.7
# Petal_Length            1.5
# Petal_Width             0.2
# Species         Iris-setosa
# Name: 10, dtype: object

# %%
cols_2_4=iris.columns[2:3]
iris[cols_2_4]
# Out:
#      Petal_Length
# 0             1.4
# 1             1.4
# 2             1.3
# 3             1.5
# 4             1.4
# ..            ...
# 145           5.2
# 146           5.0
# 147           5.2
# 148           5.4
# 149           5.1
#
# [150 rows x 1 columns]

# %%
iris[iris.columns[2:4]].iloc[5:10]
# Out:
#    Petal_Length  Petal_Width
# 5           1.7          0.4
# 6           1.4          0.3
# 7           1.5          0.2
# 8           1.4          0.2
# 9           1.5          0.1

# %%
####print for NULL true flase

import pandas as pd
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']
iris = pd.read_csv(csv_url, names = col_names)
#iris = pd.read_csv(csv_url, header = None)
##print(iris)

df1 = pd.DataFrame(iris)
##print(df)
df1.head()
##df1.isnull()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df1.isnull().sum(axis = 1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Length: 150, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64

# %%
df1.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Species          object
# dtype: object

# %%
df1.Sepal_Length.isnull().sum()
# Out:
# 0

# %%
df1.Petal_Length.isnull().sum()
# Out:
# 0

# %%
import pandas as pd 
import numpy as np
df2={
    'Name':['Santoshi','Siddhi','Ankita','Shubhali'],
    'State':['Mh',np.NaN ,'Up','Goa'],
    'Gender':['F','F','F','F'],
    'Score':[60,70,80,np.NaN]
}
col_names = ['Name','State','Gender','Score']
df3 = pd.DataFrame(df2)
df3
# Out:
#        Name State Gender  Score
# 0  Santoshi    Mh      F   60.0
# 1    Siddhi   NaN      F   70.0
# 2    Ankita    Up      F   80.0
# 3  Shubhali   Goa      F    NaN

# %%
df3.isnull()
# Out:
#     Name  State  Gender  Score
# 0  False  False   False  False
# 1  False   True   False  False
# 2  False  False   False  False
# 3  False  False   False   True

# %%
df3.isnull().any()
# Out:
# Name      False
# State      True
# Gender    False
# Score      True
# dtype: bool

# %%
df3.isnull().sum(axis = 1)
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Name      0
# State     1
# Gender    0
# Score     1
# dtype: int64

# %%
df3.isna().sum()
# Out:
# Name      0
# State     1
# Gender    0
# Score     1
# dtype: int64

# %%
df3.Gender.isnull().sum()
# Out:
# 0

# %%
df3.groupby(['Gender'])['Score'].apply(lambda x:x.isnull().sum())
# Out:
# Gender
# F    1
# Name: Score, dtype: int64

# %%
df3.dtypes
# Out:
# Name       object
# State      object
# Gender     object
# Score     float64
# dtype: object

# %%
from sklearn import preprocessing

# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()
df4 = pd.DataFrame(iris.data,columns=iris.feature_names)

# %% [markdown]
# for My Extra Learning

# %%
import pandas as pd
import matplotlib.pyplot as plt
  
# A dictionary which represents data
data_dict = { 'name':['p1','p2','p3','p4','p5','p6'],
              'age':[20,20,21,20,21,20],
              'math_marks':[100,90,91,98,92,95],
              'physics_marks':[90,100,91,92,98,95],
              'chem_marks' :[93,89,99,92,94,92]
              }
  
# creating a data frame object
df = pd.DataFrame(data_dict)
  
df.head()
# Out:
#   name  age  math_marks  physics_marks  chem_marks
# 0   p1   20         100             90          93
# 1   p2   20          90            100          89
# 2   p3   21          91             91          99
# 3   p4   20          98             92          92
# 4   p5   21          92             98          94

# %%
# scatter plot
df.plot(kind = 'scatter',
        x = 'math_marks',
        y = 'physics_marks',
        color = 'red')
  
# set the title
plt.title('ScatterPlot')
  
# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-55bc8b68a74c> in <module>()
#       6
#       7 # set the title
# ----> 8 plt.title('ScatterPlot')
#       9
#      10 # show the plot
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
# bar plot
df.plot(kind = 'bar',
        x = 'name',
        y = 'physics_marks',
        color = 'green')
  
# set the title
plt.title('BarPlot')
  
# show the plot
plt.show()
